# %%
import numpy as np
import gmms

# %% [markdown]
# ## Switch from Python to Cython backend

# %%
print('Distance tools implementation: {}'.format(gmms.distancetools.__implementation__))
print('CB10 implementation: {}'.format(gmms.FoulserPiggottGoda2015.__implementation__))
# Out:
# Distance tools implementation: Python
# CB10 implementation: Python

# %%
gmms.distancetools.select_backend('Cython')
gmms.FoulserPiggottGoda2015.select_backend('Cython')

# %%
print('Distance tools implementation: {}'.format(gmms.distancetools.__implementation__))
print('CB10 implementation: {}'.format(gmms.FoulserPiggottGoda2015.__implementation__))
# Out:
# Distance tools implementation: Cython
# CB10 implementation: Cython

# %% [markdown]
# # Example: 2003 Tokachi Earthquake

# %% [markdown]
# ## Earthquake parameters

# %%
M       = 8.29
hyp_lat = 41.7796
hyp_lon = 144.0786
hyp_Z   = 25.0101

# %% [markdown]
# ## Fault model

# %%
ULC_lat = 42.1796
ULC_lon = 144.8114
fZtor = 23.3
flength = 120.
fwidth  = 100.
fstrike = 230.
fdip    = 20.
frake   = 90.
fins = 0
fint = 1

# %% [markdown]
# ## Site parameters

# %%
site_lat  = 40.9255
site_lon  = 140.9527
site_Vs30 = 289.219

# %% [markdown]
# ## Convert to arrays

# %%
vals = []
for val in zip([ULC_lat,ULC_lon,flength,fwidth,fstrike,fdip,frake,fZtor,site_lat,site_lon,site_Vs30]):
    if isinstance(val[0],np.ndarray):
        vals.append(val[0])
    elif isinstance(val[0], (int, float)):
        vals.append(np.array([float(val[0])]))
    elif isinstance(val[0], (list, tuple)):
        vals.append(np.array(val[0], dtype=float))
    else:
        vals.append(val[0])
[ULC_lat,ULC_lon,flength,fwidth,fstrike,fdip,frake,fZtor,site_lat,site_lon,site_Vs30] = vals

# %% [markdown]
# ## Compute fault parameters

# %%
[URC_lat,URC_lon] = gmms.faulttools.get_fault_URC(ULC_lat,ULC_lon,flength,fstrike)
[fnm,frv,fmech]   = gmms.faulttools.get_faulting_style(frake)

# %% [markdown]
# ## Compute site parameters

# %%
[_,R_rup,_] = gmms.distancetools.get_distances(site_lat,site_lon,ULC_lat,ULC_lon,URC_lat,URC_lon,fwidth,flength,fdip,fstrike,fZtor)

# %%
print('Rrup = {:.2f} km'.format(R_rup[0]))
# Out:
# Rrup = 224.55 km

# %% [markdown]
# ## Compute ground motion intensity measures

# %% [markdown]
# ### Ia

# %%
[mu,phi,tau] = gmms.FoulserPiggottGoda2015.FoulserPiggottGoda2015(0,M,hyp_lat,hyp_lon,hyp_Z,R_rup,site_Vs30,fins,fint,fnm,frv)
print('Ia = {:.2f} m/s'.format(np.exp(mu[0])))
# Out:
# Ia = 0.26 m/s

# %% [markdown]
# ### CAV

# %%
[mu,phi,tau] = gmms.FoulserPiggottGoda2015.FoulserPiggottGoda2015(1,M,hyp_lat,hyp_lon,hyp_Z,R_rup,site_Vs30,fins,fint,fnm,frv)
print('CAV = {:.2f} m/s'.format(np.exp(mu[0])))
# Out:
# CAV = 11.62 m/s
